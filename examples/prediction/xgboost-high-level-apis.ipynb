# %% [markdown]
# # Train and deploy on Kubeflow from Notebooks
#
# This notebook introduces you to using Kubeflow Fairing to train and deploy a model to Kubeflow on Google Kubernetes Engine (GKE), and Google Cloud ML Engine. This notebook demonstrate how to:
#
# * Train an XGBoost model in a local notebook,
# * Use Kubeflow Fairing to train an XGBoost model remotely on Kubeflow,
# * Use Kubeflow Fairing to train an XGBoost model remotely on Cloud ML Engine,
# * Use Kubeflow Fairing to deploy a trained model to Kubeflow, and
# * Call the deployed endpoint for predictions.
#
# To learn more about how to run this notebook locally, see the guide to [training and deploying on GCP from a local notebook][gcp-local-notebook].
#
# [gcp-local-notebook]: https://kubeflow.org/docs/fairing/gcp-local-notebook/

# %% [markdown]
# ## Set up your notebook for training an XGBoost model
#
# Import the libraries required to train this model.

# %%
import argparse
import logging
import joblib
import sys
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from xgboost import XGBRegressor

# %%
logging.basicConfig(format='%(message)s')
logging.getLogger().setLevel(logging.INFO)

# %% [markdown]
# Define a function to split the input file into training and testing datasets.

# %%
def read_input(file_name, test_size=0.25):
    """Read input data and split it into train and test."""
    data = pd.read_csv(file_name)
    data.dropna(axis=0, subset=['SalePrice'], inplace=True)

    y = data.SalePrice
    X = data.drop(['SalePrice'], axis=1).select_dtypes(exclude=['object'])

    train_X, test_X, train_y, test_y = train_test_split(X.values,
                                                      y.values,
                                                      test_size=test_size,
                                                      shuffle=False)

    imputer = SimpleImputer()
    train_X = imputer.fit_transform(train_X)
    test_X = imputer.transform(test_X)

    return (train_X, train_y), (test_X, test_y)

# %% [markdown]
# Define functions to train, evaluate, and save the trained model.

# %%
def train_model(train_X,
                train_y,
                test_X,
                test_y,
                n_estimators,
                learning_rate):
    """Train the model using XGBRegressor."""
    model = XGBRegressor(n_estimators=n_estimators, learning_rate=learning_rate)

    model.fit(train_X,
            train_y,
            early_stopping_rounds=40,
            eval_set=[(test_X, test_y)])

    print("Best RMSE on eval: %.2f with %d rounds",
               model.best_score,
               model.best_iteration+1)
    return model

def eval_model(model, test_X, test_y):
    """Evaluate the model performance."""
    predictions = model.predict(test_X)
    logging.info("mean_absolute_error=%.2f", mean_absolute_error(predictions, test_y))

def save_model(model, model_file):
    """Save XGBoost model for serving."""
    joblib.dump(model, model_file)
    logging.info("Model export success: %s", model_file)

# %% [markdown]
# Define a class for your model, with methods for training and prediction.

# %%
class HousingServe(object):
    
    def __init__(self):
        self.train_input = "ames_dataset/train.csv"
        self.n_estimators = 50
        self.learning_rate = 0.1
        self.model_file = "trained_ames_model.dat"
        self.model = None

    def train(self):
        (train_X, train_y), (test_X, test_y) = read_input(self.train_input)
        model = train_model(train_X,
                          train_y,
                          test_X,
                          test_y,
                          self.n_estimators,
                          self.learning_rate)

        eval_model(model, test_X, test_y)
        save_model(model, self.model_file)

    def predict(self, X, feature_names):
        """Predict using the model for given ndarray."""
        if not self.model:
            self.model = joblib.load(self.model_file)
        # Do any preprocessing
        prediction = self.model.predict(data=X)
        # Do any postprocessing
        return [[prediction.item(0), prediction.item(0)]]

# %% [markdown]
# ## Train an XGBoost model in a notebook
#
# Call `HousingServe().train()` to train your model, and then evaluate and save your trained model.

# %%
HousingServe().train()
# Out:
# [18:55:37] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:177514
# Will train until validation_0-rmse hasn't improved in 40 rounds.
# [1]	validation_0-rmse:161858
# [2]	validation_0-rmse:147237
# [3]	validation_0-rmse:134132
# [4]	validation_0-rmse:122224
# [5]	validation_0-rmse:111538
# [6]	validation_0-rmse:102142
# [7]	validation_0-rmse:93392.3
# [8]	validation_0-rmse:85824.6
# [9]	validation_0-rmse:79667.6
# [10]	validation_0-rmse:73463.4
# [11]	validation_0-rmse:68059.4
# [12]	validation_0-rmse:63350.5
# [13]	validation_0-rmse:59732.1
# [14]	validation_0-rmse:56260.7
# [15]	validation_0-rmse:53392.6
# [16]	validation_0-rmse:50770.8
# [17]	validation_0-rmse:48107.8
# [18]	validation_0-rmse:45923.9
# [19]	validation_0-rmse:44154.2
# [20]	validation_0-rmse:42488.1
# [21]	validation_0-rmse:41263.3
# [22]	validation_0-rmse:40212.8
# [23]	validation_0-rmse:39089.1
# [24]	validation_0-rmse:37691.1
# [25]	validation_0-rmse:36875.2
# [26]	validation_0-rmse:36276.2
# [27]	validation_0-rmse:35444.1
# [28]	validation_0-rmse:34831.5
# [29]	validation_0-rmse:34205.4
# [30]	validation_0-rmse:33831.9
# [31]	validation_0-rmse:33183.6
# [32]	validation_0-rmse:33019.4
# [33]	validation_0-rmse:32680
# [34]	validation_0-rmse:32438.5
# [35]	validation_0-rmse:32130.4
# [36]	validation_0-rmse:31644.2
# [37]	validation_0-rmse:31248.9
# [38]	validation_0-rmse:31059.8
# [39]	validation_0-rmse:30862.4
# [40]	validation_0-rmse:30754
# [41]	validation_0-rmse:30561.6
# [42]	validation_0-rmse:30416.9
# [43]	validation_0-rmse:30156.4
# [44]	validation_0-rmse:29852.9
# [45]	validation_0-rmse:29486.6
# [46]	validation_0-rmse:29158.8
# [47]	validation_0-rmse:29017
# [48]	validation_0-rmse:28973.9
# [49]	validation_0-rmse:28787.7
# mean_absolute_error=18173.15
# Model export success: trained_ames_model.dat
# Best RMSE on eval: %.2f with %d rounds 28787.720703 50

# %% [markdown]
# ## Set up Kubeflow Fairing for training and predictions on GCP
#
# Import the `fairing` library and configure the GCP environment that your training or prediction job will run in.

# %%
import os
import fairing

# Setting up google container repositories (GCR) for storing output containers
# You can use any docker container registry istead of GCR
GCP_PROJECT = fairing.cloud.gcp.guess_project_name()
DOCKER_REGISTRY = 'gcr.io/{}/fairing-job'.format(GCP_PROJECT)
PY_VERSION = ".".join([str(x) for x in sys.version_info[0:3]])
BASE_IMAGE = 'python:{}'.format(PY_VERSION)

# %% [markdown]
# ## Train an XGBoost model remotely on Kubeflow
#
# Import the `TrainJob` and `KubeflowGKEBackend` classes. Kubeflow Fairing packages the `HousingServe` class, the training data, and the training job's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the training job on Kubeflow.

# %%
from fairing import TrainJob
from fairing.backends import KubeflowGKEBackend
train_job = TrainJob(HousingServe, BASE_IMAGE, input_files=['ames_dataset/train.csv', "requirements.txt"],
                     docker_registry=DOCKER_REGISTRY, backend=KubeflowGKEBackend())
train_job.submit()
# Out:
# Using builder: <class 'fairing.builders.docker.docker.DockerBuilder'>
# Building the docker image.
# Building image using docker
# Docker command: ['python', '/app/function_shim.py', '--serialized_fn_file', '/app/pickled_fn.p']
# /Users/cartick/Documents/workspace/fairing/venv/lib/python3.7/site-packages/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_89gq0t3d
# /Users/cartick/Documents/workspace/fairing/venv/lib/python3.7/site-packages/fairing/__init__.py already exists in Fairing context, skipping...
# Building docker image gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:26A3FC51...
# Build output: Step 1/7 : FROM python:3.7.2
# Build output:
# Build output: ---> 2053ca75899e
# Build output: Step 2/7 : WORKDIR /app/
# Build output:
# Build output: ---> Using cache
# Build output: ---> 2c7f8a216fa8
# Build output: Step 3/7 : ENV FAIRING_RUNTIME 1
# Build output:
# Build output: ---> Using cache
# Build output: ---> 13640ae5453f
# Build output: Step 4/7 : COPY /app//requirements.txt /app/
# Build output:
# Build output: ---> 65b03bec95c5
# Build output: Step 5/7 : RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# Build output:
# Build output: ---> Running in c9e641d03d9b
# Build output: Collecting pandas (from -r requirements.txt (line 1))
# Build output: Downloading https://files.pythonhosted.org/packages/22/e6/2d47835f91eb010036be207581fa113fb4e3822ec1b4bafb0d3d105fede6/pandas-0.24.2-cp37-cp37m-manylinux1_x86_64.whl (10.1MB)
# Build output: Collecting joblib (from -r requirements.txt (line 2))
# Build output: Downloading https://files.pythonhosted.org/packages/cd/c1/50a758e8247561e58cb87305b1e90b171b8c767b15b12a1734001f41d356/joblib-0.13.2-py2.py3-none-any.whl (278kB)
# Build output: Collecting numpy (from -r requirements.txt (line 3))
# Build output: Downloading https://files.pythonhosted.org/packages/fc/d1/45be1144b03b6b1e24f9a924f23f66b4ad030d834ad31fb9e5581bd328af/numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3MB)
# Build output: Collecting xgboost (from -r requirements.txt (line 4))
# Build output: Downloading https://files.pythonhosted.org/packages/c1/24/5fe7237b2eca13ee0cfb100bec8c23f4e69ce9df852a64b0493d49dae4e0/xgboost-0.90-py2.py3-none-manylinux1_x86_64.whl (142.8MB)
# Build output: Collecting scikit-learn>=0.21.0 (from -r requirements.txt (line 5))
# Build output: Downloading https://files.pythonhosted.org/packages/21/a4/a48bd4b0d15395362b561df7e7247de87291105eb736a3b2aaffebf437b9/scikit_learn-0.21.2-cp37-cp37m-manylinux1_x86_64.whl (6.7MB)
# Build output: Collecting seldon-core (from -r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/5e/a8/3b3295e38a023980a6c51addcbecf8cfc45770e7d16c2df687f34f636860/seldon_core-0.3.0-py3-none-any.whl
# Build output: Collecting python-dateutil>=2.5.0 (from pandas->-r requirements.txt (line 1))
# Build output: Downloading https://files.pythonhosted.org/packages/41/17/c62faccbfbd163c7f57f3844689e3a78bae1f403648a6afb1d0866d87fbb/python_dateutil-2.8.0-py2.py3-none-any.whl (226kB)
# Build output: Collecting pytz>=2011k (from pandas->-r requirements.txt (line 1))
# Build output: Downloading https://files.pythonhosted.org/packages/3d/73/fe30c2daaaa0713420d0382b16fbb761409f532c56bdcc514bf7b6262bb6/pytz-2019.1-py2.py3-none-any.whl (510kB)
# Build output: Collecting scipy (from xgboost->-r requirements.txt (line 4))
# Build output: Downloading https://files.pythonhosted.org/packages/5d/bd/c0feba81fb60e231cf40fc8a322ed5873c90ef7711795508692b1481a4ae/scipy-1.3.0-cp37-cp37m-manylinux1_x86_64.whl (25.2MB)
# Build output: Collecting pyyaml (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/a3/65/837fefac7475963d1eccf4aa684c23b95aa6c1d033a2c5965ccb11e22623/PyYAML-5.1.1.tar.gz (274kB)
# Build output: Collecting tensorflow (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/d4/29/6b4f1e02417c3a1ccc85380f093556ffd0b35dc354078074c5195c8447f2/tensorflow-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (92.6MB)
# Build output: Collecting jaeger-client==3.13.0 (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/c8/a2/e9bd04cd660cbdffe0598173be068be23099fbd68e7a4a89b74440509130/jaeger-client-3.13.0.tar.gz (77kB)
# Build output: Collecting redis (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/ac/a7/cff10cc5f1180834a3ed564d148fb4329c989cbb1f2e196fc9a10fa07072/redis-3.2.1-py2.py3-none-any.whl (65kB)
# Build output: Collecting opentracing<2,>=1.2.2 (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/06/c2/90b35a1abdc639a5c6000d8202c70217d60e80f5b328870efb73fda71115/opentracing-1.3.0.tar.gz
# Build output: Collecting protobuf (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/ce/86/9f6123c4c6f481862f286dbe13aa2e97bdedd7662f5fc3033c1a41f32f88/protobuf-3.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.2MB)
# Build output: Collecting flatbuffers (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/c9/84/adf5837f96c39990bc55afdfddf460b38b4562f50341359afa32e4a98de7/flatbuffers-1.11-py2.py3-none-any.whl
# Build output: Collecting grpcio (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/a2/66/a44fc7eb9bd3a9c480a70c30306f175521ca0531e2cf1ca54b74a450fdb9/grpcio-1.21.1-cp37-cp37m-manylinux1_x86_64.whl (2.2MB)
# Build output: Collecting Flask-OpenTracing==0.2.0 (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/1d/c4/0546b854a3f42af9ef959df9bd1108903698e175e7a07c057cdfaeeef718/Flask_OpenTracing-0.2.0-py2.py3-none-any.whl
# Build output: Collecting grpcio-opentracing (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/db/82/2fcad380697c3dab25de76ee590bcab3eb9bbfb4add916044d7e83ec2b10/grpcio_opentracing-1.1.4-py3-none-any.whl
# Build output: Collecting flask (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/9a/74/670ae9737d14114753b8c8fdf2e8bd212a05d3b361ab15b44937dfd40985/Flask-1.0.3-py2.py3-none-any.whl (92kB)
# Build output: Collecting requests (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/51/bd/23c926cd341ea6b7dd0b2a00aba99ae0f828be89d72b2190f27c11d4b7fb/requests-2.22.0-py2.py3-none-any.whl (57kB)
# Build output: Collecting flask-cors (from seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/78/38/e68b11daa5d613e3a91e4bf3da76c94ac9ee0d9cd515af9c1ab80d36f709/Flask_Cors-3.0.8-py2.py3-none-any.whl
# Build output: Collecting six>=1.5 (from python-dateutil>=2.5.0->pandas->-r requirements.txt (line 1))
# Build output: Downloading https://files.pythonhosted.org/packages/73/fb/00a976f728d0d1fecfe898238ce23f502a721c0ac0ecfedb80e0d88c64e9/six-1.12.0-py2.py3-none-any.whl
# Build output: Collecting absl-py>=0.1.6 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/da/3f/9b0355080b81b15ba6a9ffcf1f5ea39e307a2778b2f2dc8694724e8abd5b/absl-py-0.7.1.tar.gz (99kB)
# Build output: Collecting keras-preprocessing>=1.0.5 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/28/6a/8c1f62c37212d9fc441a7e26736df51ce6f0e38455816445471f10da4f0a/Keras_Preprocessing-1.1.0-py2.py3-none-any.whl (41kB)
# Build output: Collecting keras-applications>=1.0.6 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
# Build output: Collecting tensorboard<1.14.0,>=1.13.0 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
# Build output: Collecting gast>=0.2.0 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Build output: Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
# Build output: Collecting termcolor>=1.1.0 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/8a/48/a76be51647d0eb9f10e2a4511bf3ffb8cc1e6b14e9e4fab46173aa79f981/termcolor-1.1.0.tar.gz
# Build output: Collecting astor>=0.6.0 (from tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/d1/4f/950dfae467b384fc96bc6469de25d832534f6b4441033c39f914efd13418/astor-0.8.0-py2.py3-none-any.whl
# Build output: Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/site-packages (from tensorflow->seldon-core->-r requirements.txt (line 6)) (0.33.1)
# Build output: Collecting threadloop<2,>=1 (from jaeger-client==3.13.0->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/d3/1d/8398c1645b97dc008d3c658e04beda01ede3d90943d40c8d56863cf891bd/threadloop-1.0.2.tar.gz
# Build output: Collecting thrift (from jaeger-client==3.13.0->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/c6/b4/510617906f8e0c5660e7d96fbc5585113f83ad547a3989b80297ac72a74c/thrift-0.11.0.tar.gz (52kB)
# Build output: Collecting tornado<5,>=4.3 (from jaeger-client==3.13.0->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/e3/7b/e29ab3d51c8df66922fea216e2bddfcb6430fb29620e5165b16a216e0d3c/tornado-4.5.3.tar.gz (484kB)
# Build output: Requirement already satisfied: setuptools in /usr/local/lib/python3.7/site-packages (from protobuf->seldon-core->-r requirements.txt (line 6)) (40.8.0)
# Build output: Collecting click>=5.1 (from flask->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
# Build output: Collecting Jinja2>=2.10 (from flask->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/1d/e7/fd8b501e7a6dfe492a433deb7b9d833d39ca74916fa8bc63dd1a4947a671/Jinja2-2.10.1-py2.py3-none-any.whl (124kB)
# Build output: Collecting Werkzeug>=0.14 (from flask->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/9f/57/92a497e38161ce40606c27a86759c6b92dd34fcdb33f64171ec559257c02/Werkzeug-0.15.4-py2.py3-none-any.whl (327kB)
# Build output: Collecting itsdangerous>=0.24 (from flask->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/76/ae/44b03b253d6fade317f32c24d100b3b35c2239807046a4c953c7b89fa49e/itsdangerous-1.1.0-py2.py3-none-any.whl
# Build output: Collecting certifi>=2017.4.17 (from requests->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/60/75/f692a584e85b7eaba0e03827b3d51f45f571c2e793dd731e598828d380aa/certifi-2019.3.9-py2.py3-none-any.whl (158kB)
# Build output: Collecting chardet<3.1.0,>=3.0.2 (from requests->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/bc/a9/01ffebfb562e4274b6487b4bb1ddec7ca55ec7510b22e4c51f14098443b8/chardet-3.0.4-py2.py3-none-any.whl (133kB)
# Build output: Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 (from requests->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/e6/60/247f23a7121ae632d62811ba7f273d0e58972d75e58a94d329d51550a47d/urllib3-1.25.3-py2.py3-none-any.whl (150kB)
# Build output: Collecting idna<2.9,>=2.5 (from requests->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/14/2c/cd551d81dbe15200be1cf41cd03869a46fe7226e7450af7a6545bfc474c9/idna-2.8-py2.py3-none-any.whl (58kB)
# Build output: Collecting h5py (from keras-applications>=1.0.6->tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/8e/fd/2ca5c4f4ed33ac4178f9c4d551e3946ab480866e3cd67a65a67a4bb35367/h5py-2.9.0-cp37-cp37m-manylinux1_x86_64.whl (2.8MB)
# Build output: Collecting markdown>=2.6.8 (from tensorboard<1.14.0,>=1.13.0->tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/c0/4e/fd492e91abdc2d2fcb70ef453064d980688762079397f779758e055f6575/Markdown-3.1.1-py2.py3-none-any.whl (87kB)
# Build output: Collecting mock>=2.0.0 (from tensorflow-estimator<1.14.0rc0,>=1.13.0->tensorflow->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Build output: Collecting MarkupSafe>=0.23 (from Jinja2>=2.10->flask->seldon-core->-r requirements.txt (line 6))
# Build output: Downloading https://files.pythonhosted.org/packages/98/7b/ff284bd8c80654e471b769062a9b43cc5d03e7a615048d96f4619df8d420/MarkupSafe-1.1.1-cp37-cp37m-manylinux1_x86_64.whl
# Build output: Installing collected packages: six, python-dateutil, numpy, pytz, pandas, joblib, scipy, xgboost, scikit-learn, pyyaml, absl-py, keras-preprocessing, h5py, keras-applications, grpcio, markdown, protobuf, Werkzeug, tensorboard, gast, mock, tensorflow-estimator, termcolor, astor, tensorflow, tornado, threadloop, thrift, opentracing, jaeger-client, redis, flatbuffers, click, MarkupSafe, Jinja2, itsdangerous, flask, Flask-OpenTracing, grpcio-opentracing, certifi, chardet, urllib3, idna, requests, flask-cors, seldon-core
# Build output: Running setup.py install for pyyaml: started
# Build output: Running setup.py install for pyyaml: finished with status 'done'
# Build output: Running setup.py install for absl-py: started
# Build output: Running setup.py install for absl-py: finished with status 'done'
# Build output: Running setup.py install for gast: started
# Build output: Running setup.py install for gast: finished with status 'done'
# Build output: Running setup.py install for termcolor: started
# Build output: Running setup.py install for termcolor: finished with status 'done'
# Build output: Running setup.py install for tornado: started
# Build output: Running setup.py install for tornado: finished with status 'done'
# Build output: Running setup.py install for threadloop: started
# Build output: Running setup.py install for threadloop: finished with status 'done'
# Build output: Running setup.py install for thrift: started
# Build output: Running setup.py install for thrift: finished with status 'done'
# Build output: Running setup.py install for opentracing: started
# Build output: Running setup.py install for opentracing: finished with status 'done'
# Build output: Running setup.py install for jaeger-client: started
# Build output: Running setup.py install for jaeger-client: finished with status 'done'
# Build output: Successfully installed Flask-OpenTracing-0.2.0 Jinja2-2.10.1 MarkupSafe-1.1.1 Werkzeug-0.15.4 absl-py-0.7.1 astor-0.8.0 certifi-2019.3.9 chardet-3.0.4 click-7.0 flask-1.0.3 flask-cors-3.0.8 flatbuffers-1.11 gast-0.2.2 grpcio-1.21.1 grpcio-opentracing-1.1.4 h5py-2.9.0 idna-2.8 itsdangerous-1.1.0 jaeger-client-3.13.0 joblib-0.13.2 keras-applications-1.0.8 keras-preprocessing-1.1.0 markdown-3.1.1 mock-3.0.5 numpy-1.16.4 opentracing-1.3.0 pandas-0.24.2 protobuf-3.8.0 python-dateutil-2.8.0 pytz-2019.1 pyyaml-5.1.1 redis-3.2.1 requests-2.22.0 scikit-learn-0.21.2 scipy-1.3.0 seldon-core-0.3.0 six-1.12.0 tensorboard-1.13.1 tensorflow-1.13.1 tensorflow-estimator-1.13.0 termcolor-1.1.0 threadloop-1.0.2 thrift-0.11.0 tornado-4.5.3 urllib3-1.25.3 xgboost-0.90
# Build output: You are using pip version 19.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
# Build output: ---> cf9bd5ec2ec1
# Build output: Step 6/7 : COPY /app/ /app/
# Build output:
# Build output: ---> 7ce163e5499e
# Build output: Step 7/7 : CMD python /app/function_shim.py --serialized_fn_file /app/pickled_fn.p
# Build output:
# Build output: ---> Running in 8c4f6b884444
# Build output: ---> b490ae841537
# Push finished: {'ID': 'sha256:b490ae841537cef98aea1cf7ecb711d406bebb793dd4e263fb24db6876eb542d'}
# Build output: Successfully built b490ae841537
# Build output: Successfully tagged gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:26A3FC51
# Publishing image gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:26A3FC51...
# Push output: The push refers to repository [gcr.io/caip-dexter-bugbash/fairing-job/fairing-job] None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Pushing [===>                                               ]  35.33kB/514.8kB
# Push output: Pushing [==================================================>]  524.8kB
# Push output: Pushing [==================================================>]     512B
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Pushing [>                                                  ]  533.9kB/969.2MB
# Push output: Pushing [==================================================>]   2.56kB
# Push output: Pushing [>                                                  ]  1.615MB/969.2MB
# Push output: Pushing [>                                                  ]  3.787MB/969.2MB
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Pushing [>                                                  ]  5.897MB/969.2MB
# Push output: Pushing [>                                                  ]  8.026MB/969.2MB
# Push output: Pushing [>                                                  ]  10.72MB/969.2MB
# Push output: Layer already exists None
# Push output: Pushing [>                                                  ]  13.47MB/969.2MB
# Push output: Layer already exists None
# Push output: Pushing [>                                                  ]  16.14MB/969.2MB
# Push output: Pushing [>                                                  ]  17.82MB/969.2MB
# Push output: Pushing [=>                                                 ]  20.04MB/969.2MB
# Push output: Layer already exists None
# Push output: Pushing [=>                                                 ]  22.22MB/969.2MB
# Push output: Layer already exists None
# Push output: Pushing [=>                                                 ]  23.89MB/969.2MB
# Push output: Pushing [=>                                                 ]  26.66MB/969.2MB
# Push output: Pushing [=>                                                 ]  28.81MB/969.2MB
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Pushing [=>                                                 ]  30.94MB/969.2MB
# Push output: Pushing [=>                                                 ]  33.09MB/969.2MB
# Push output: Pushing [=>                                                 ]  35.79MB/969.2MB
# Push output: Pushing [=>                                                 ]  38.58MB/969.2MB
# Push output: Pushed None
# Push output: Pushed None
# Push output: Pushing [==>                                                ]  41.92MB/969.2MB
# Push output: Pushing [==>                                                ]  45.26MB/969.2MB
# Push output: Pushing [==>                                                ]   48.6MB/969.2MB
# Push output: Pushing [==>                                                ]  51.95MB/969.2MB
# Push output: Pushing [==>                                                ]  54.73MB/969.2MB
# Push output: Pushing [==>                                                ]   56.4MB/969.2MB
# Push output: Pushing [===>                                               ]  58.63MB/969.2MB
# Push output: Pushing [===>                                               ]   60.3MB/969.2MB
# Push output: Pushing [===>                                               ]  61.97MB/969.2MB
# Push output: Pushing [===>                                               ]  64.76MB/969.2MB
# Push output: Pushing [===>                                               ]  67.46MB/969.2MB
# Push output: Pushing [===>                                               ]  70.25MB/969.2MB
# Push output: Pushing [===>                                               ]  72.48MB/969.2MB
# Push output: Pushing [===>                                               ]  74.71MB/969.2MB
# Push output: Pushing [===>                                               ]  77.49MB/969.2MB
# Push output: Pushing [====>                                              ]  80.28MB/969.2MB
# Push output: Pushing [====>                                              ]  83.62MB/969.2MB
# Push output: Pushing [====>                                              ]   86.4MB/969.2MB
# Push output: Pushing [====>                                              ]  89.13MB/969.2MB
# Push output: Pushing [====>                                              ]  91.81MB/969.2MB
# Push output: Pushing [====>                                              ]  93.97MB/969.2MB
# Push output: Pushing [====>                                              ]  96.62MB/969.2MB
# Push output: Pushing [=====>                                             ]  99.33MB/969.2MB
# Push output: Pushing [=====>                                             ]    102MB/969.2MB
# Push output: Pushing [=====>                                             ]  104.8MB/969.2MB
# Push output: Pushing [=====>                                             ]  107.5MB/969.2MB
# Push output: Pushing [=====>                                             ]  109.7MB/969.2MB
# Push output: Pushing [=====>                                             ]  111.9MB/969.2MB
# Push output: Pushing [=====>                                             ]  114.7MB/969.2MB
# Push output: Pushing [======>                                            ]  116.8MB/969.2MB
# Push output: Pushing [======>                                            ]    119MB/969.2MB
# Push output: Pushing [======>                                            ]  119.6MB/969.2MB
# Push output: Pushing [======>                                            ]  121.7MB/969.2MB
# Push output: Pushing [======>                                            ]  123.9MB/969.2MB
# Push output: Pushing [======>                                            ]  124.4MB/969.2MB
# Push output: Pushing [======>                                            ]  126.6MB/969.2MB
# Push output: Pushing [======>                                            ]  129.3MB/969.2MB
# Push output: Pushing [======>                                            ]  130.3MB/969.2MB
# Push output: Pushing [======>                                            ]  132.5MB/969.2MB
# Push output: Pushing [======>                                            ]  135.1MB/969.2MB
# Push output: Pushing [=======>                                           ]  137.8MB/969.2MB
# Push output: Pushing [=======>                                           ]  140.5MB/969.2MB
# Push output: Pushing [=======>                                           ]  141.5MB/969.2MB
# Push output: Pushing [=======>                                           ]  144.2MB/969.2MB
# Push output: Pushing [=======>                                           ]  146.9MB/969.2MB
# Push output: Pushing [=======>                                           ]  149.5MB/969.2MB
# Push output: Pushing [=======>                                           ]  152.2MB/969.2MB
# Push output: Pushing [=======>                                           ]  154.3MB/969.2MB
# Push output: Pushing [========>                                          ]  156.4MB/969.2MB
# Push output: Pushing [========>                                          ]  159.2MB/969.2MB
# Push output: Pushing [========>                                          ]  163.1MB/969.2MB
# Push output: Pushing [========>                                          ]    167MB/969.2MB
# Push output: Pushing [========>                                          ]  168.7MB/969.2MB
# Push output: Pushing [========>                                          ]  171.5MB/969.2MB
# Push output: Pushing [=========>                                         ]  174.8MB/969.2MB
# Push output: Pushing [=========>                                         ]    177MB/969.2MB
# Push output: Pushing [=========>                                         ]  178.7MB/969.2MB
# Push output: Pushing [=========>                                         ]  180.4MB/969.2MB
# Push output: Pushing [=========>                                         ]    182MB/969.2MB
# Push output: Pushing [=========>                                         ]  184.3MB/969.2MB
# Push output: Pushing [=========>                                         ]  186.5MB/969.2MB
# Push output: Pushing [=========>                                         ]  188.7MB/969.2MB
# Push output: Pushing [=========>                                         ]  190.8MB/969.2MB
# Push output: Pushing [=========>                                         ]    193MB/969.2MB
# Push output: Pushing [==========>                                        ]    194MB/969.2MB
# Push output: Pushing [==========>                                        ]  196.2MB/969.2MB
# Push output: Pushing [==========>                                        ]  198.9MB/969.2MB
# Push output: Pushing [==========>                                        ]  199.5MB/969.2MB
# Push output: Pushing [==========>                                        ]  202.2MB/969.2MB
# Push output: Pushing [==========>                                        ]  204.9MB/969.2MB
# Push output: Pushing [==========>                                        ]  205.4MB/969.2MB
# Push output: Pushing [==========>                                        ]    206MB/969.2MB
# Push output: Pushing [==========>                                        ]  207.6MB/969.2MB
# Push output: Pushing [==========>                                        ]  209.7MB/969.2MB
# Push output: Pushing [==========>                                        ]  210.8MB/969.2MB
# Push output: Pushing [==========>                                        ]  212.4MB/969.2MB
# Push output: Pushing [===========>                                       ]  214.6MB/969.2MB
# Push output: Pushing [===========>                                       ]  216.2MB/969.2MB
# Push output: Pushing [===========>                                       ]  218.4MB/969.2MB
# Push output: Pushing [===========>                                       ]  221.1MB/969.2MB
# Push output: Pushing [===========>                                       ]  222.7MB/969.2MB
# Push output: Pushing [===========>                                       ]  224.4MB/969.2MB
# Push output: Pushing [===========>                                       ]  226.5MB/969.2MB
# Push output: Pushing [===========>                                       ]  228.7MB/969.2MB
# Push output: Pushing [===========>                                       ]  230.9MB/969.2MB
# Push output: Pushing [===========>                                       ]  232.5MB/969.2MB
# Push output: Pushing [============>                                      ]  235.3MB/969.2MB
# Push output: Pushing [============>                                      ]  236.9MB/969.2MB
# Push output: Pushing [============>                                      ]  239.6MB/969.2MB
# Push output: Pushing [============>                                      ]  241.2MB/969.2MB
# Push output: Pushing [============>                                      ]  245.5MB/969.2MB
# Push output: Pushing [============>                                      ]  247.7MB/969.2MB
# Push output: Pushing [============>                                      ]  249.8MB/969.2MB
# Push output: Pushing [=============>                                     ]  252.5MB/969.2MB
# Push output: Pushing [=============>                                     ]  254.6MB/969.2MB
# Push output: Pushing [=============>                                     ]  257.3MB/969.2MB
# Push output: Pushing [=============>                                     ]    260MB/969.2MB
# Push output: Pushing [=============>                                     ]  262.7MB/969.2MB
# Push output: Pushing [=============>                                     ]  264.8MB/969.2MB
# Push output: Pushing [=============>                                     ]    267MB/969.2MB
# Push output: Pushing [=============>                                     ]  269.2MB/969.2MB
# Push output: Pushing [=============>                                     ]  271.3MB/969.2MB
# Push output: Pushing [==============>                                    ]    274MB/969.2MB
# Push output: Pushing [==============>                                    ]  276.1MB/969.2MB
# Push output: Pushing [==============>                                    ]  277.8MB/969.2MB
# Push output: Pushing [==============>                                    ]  279.9MB/969.2MB
# Push output: Pushing [==============>                                    ]  283.3MB/969.2MB
# Push output: Pushing [==============>                                    ]  285.5MB/969.2MB
# Push output: Pushing [==============>                                    ]  287.7MB/969.2MB
# Push output: Pushing [==============>                                    ]  289.9MB/969.2MB
# Push output: Pushing [===============>                                   ]  292.2MB/969.2MB
# Push output: Pushing [===============>                                   ]    296MB/969.2MB
# Push output: Pushing [===============>                                   ]  298.7MB/969.2MB
# Push output: Pushing [===============>                                   ]  301.4MB/969.2MB
# Push output: Pushing [===============>                                   ]  304.1MB/969.2MB
# Push output: Pushing [===============>                                   ]  306.3MB/969.2MB
# Push output: Pushing [===============>                                   ]    309MB/969.2MB
# Push output: Pushing [================>                                  ]  311.2MB/969.2MB
# Push output: Pushing [================>                                  ]  313.4MB/969.2MB
# Push output: Pushing [================>                                  ]  315.6MB/969.2MB
# Push output: Pushing [================>                                  ]  318.4MB/969.2MB
# Push output: Pushing [================>                                  ]  320.6MB/969.2MB
# Push output: Pushing [================>                                  ]  323.4MB/969.2MB
# Push output: Pushing [================>                                  ]  327.2MB/969.2MB
# Push output: Pushing [=================>                                 ]  329.9MB/969.2MB
# Push output: Pushing [=================>                                 ]  332.5MB/969.2MB
# Push output: Pushing [=================>                                 ]  335.8MB/969.2MB
# Push output: Pushing [=================>                                 ]  338.5MB/969.2MB
# Push output: Pushing [=================>                                 ]  341.2MB/969.2MB
# Push output: Pushing [=================>                                 ]    344MB/969.2MB
# Push output: Pushing [=================>                                 ]  346.2MB/969.2MB
# Push output: Pushing [=================>                                 ]  347.8MB/969.2MB
# Push output: Pushing [==================>                                ]  350.6MB/969.2MB
# Push output: Pushing [==================>                                ]  353.8MB/969.2MB
# Push output: Pushing [==================>                                ]    357MB/969.2MB
# Push output: Pushing [==================>                                ]  360.2MB/969.2MB
# Push output: Pushing [==================>                                ]  363.9MB/969.2MB
# Push output: Pushing [==================>                                ]  367.1MB/969.2MB
# Push output: Pushing [===================>                               ]  369.3MB/969.2MB
# Push output: Pushing [===================>                               ]  371.4MB/969.2MB
# Push output: Pushing [===================>                               ]  374.1MB/969.2MB
# Push output: Pushing [===================>                               ]  377.3MB/969.2MB
# Push output: Pushing [===================>                               ]  377.8MB/969.2MB
# Push output: Pushing [===================>                               ]  381.1MB/969.2MB
# Push output: Pushing [===================>                               ]  382.2MB/969.2MB
# Push output: Pushing [===================>                               ]  384.9MB/969.2MB
# Push output: Pushing [====================>                              ]  388.2MB/969.2MB
# Push output: Pushing [====================>                              ]  388.7MB/969.2MB
# Push output: Pushing [====================>                              ]  391.9MB/969.2MB
# Push output: Pushing [====================>                              ]  394.5MB/969.2MB
# Push output: Pushing [====================>                              ]  396.1MB/969.2MB
# Push output: Pushing [====================>                              ]  399.3MB/969.2MB
# Push output: Pushing [====================>                              ]  403.1MB/969.2MB
# Push output: Pushing [====================>                              ]  403.6MB/969.2MB
# Push output: Pushing [====================>                              ]  406.8MB/969.2MB
# Push output: Pushing [=====================>                             ]  407.3MB/969.2MB
# Push output: Pushing [=====================>                             ]  410.7MB/969.2MB
# Push output: Pushing [=====================>                             ]  412.9MB/969.2MB
# Push output: Pushing [=====================>                             ]  415.1MB/969.2MB
# Push output: Pushing [=====================>                             ]  417.4MB/969.2MB
# Push output: Pushing [=====================>                             ]  420.1MB/969.2MB
# Push output: Pushing [=====================>                             ]  422.9MB/969.2MB
# Push output: Pushing [======================>                            ]  426.8MB/969.2MB
# Push output: Pushing [======================>                            ]    429MB/969.2MB
# Push output: Pushing [======================>                            ]  431.3MB/969.2MB
# Push output: Pushing [======================>                            ]  432.9MB/969.2MB
# Push output: Pushing [======================>                            ]  435.1MB/969.2MB
# Push output: Pushing [======================>                            ]  444.1MB/969.2MB
# Push output: Pushing [=======================>                           ]  450.7MB/969.2MB
# Push output: Pushing [=======================>                           ]  453.5MB/969.2MB
# Push output: Pushing [=======================>                           ]  456.3MB/969.2MB
# Push output: Pushing [=======================>                           ]  458.5MB/969.2MB
# Push output: Pushing [=======================>                           ]  460.2MB/969.2MB
# Push output: Pushing [=======================>                           ]  461.9MB/969.2MB
# Push output: Pushing [=======================>                           ]  464.1MB/969.2MB
# Push output: Pushing [========================>                          ]    468MB/969.2MB
# Push output: Pushing [========================>                          ]  471.4MB/969.2MB
# Push output: Pushing [========================>                          ]  474.7MB/969.2MB
# Push output: Pushing [========================>                          ]  477.5MB/969.2MB
# Push output: Pushing [========================>                          ]  479.7MB/969.2MB
# Push output: Pushing [========================>                          ]  481.9MB/969.2MB
# Push output: Pushing [=========================>                         ]  485.3MB/969.2MB
# Push output: Pushing [=========================>                         ]  487.5MB/969.2MB
# Push output: Pushing [=========================>                         ]  490.3MB/969.2MB
# Push output: Pushing [=========================>                         ]  493.1MB/969.2MB
# Push output: Pushing [=========================>                         ]  495.3MB/969.2MB
# Push output: Pushing [=========================>                         ]    497MB/969.2MB
# Push output: Pushing [=========================>                         ]  499.8MB/969.2MB
# Push output: Pushing [=========================>                         ]    502MB/969.2MB
# Push output: Pushing [==========================>                        ]  505.3MB/969.2MB
# Push output: Pushing [==========================>                        ]  508.7MB/969.2MB
# Push output: Pushing [==========================>                        ]    512MB/969.2MB
# Push output: Pushing [==========================>                        ]  515.4MB/969.2MB
# Push output: Pushing [==========================>                        ]  519.3MB/969.2MB
# Push output: Pushing [==========================>                        ]  523.2MB/969.2MB
# Push output: Pushing [===========================>                       ]  525.4MB/969.2MB
# Push output: Pushing [===========================>                       ]  527.1MB/969.2MB
# Push output: Pushing [===========================>                       ]  529.3MB/969.2MB
# Push output: Pushing [===========================>                       ]  531.5MB/969.2MB
# Push output: Pushing [===========================>                       ]  534.3MB/969.2MB
# Push output: Pushing [===========================>                       ]  536.5MB/969.2MB
# Push output: Pushing [===========================>                       ]  539.3MB/969.2MB
# Push output: Pushing [===========================>                       ]  541.5MB/969.2MB
# Push output: Pushing [============================>                      ]  543.8MB/969.2MB
# Push output: Pushing [============================>                      ]    546MB/969.2MB
# Push output: Pushing [============================>                      ]  548.2MB/969.2MB
# Push output: Pushing [============================>                      ]  550.5MB/969.2MB
# Push output: Pushing [============================>                      ]  552.7MB/969.2MB
# Push output: Pushing [============================>                      ]  554.9MB/969.2MB
# Push output: Pushing [============================>                      ]  557.1MB/969.2MB
# Push output: Pushing [============================>                      ]  559.4MB/969.2MB
# Push output: Pushing [============================>                      ]  561.6MB/969.2MB
# Push output: Pushing [=============================>                     ]  566.1MB/969.2MB
# Push output: Pushing [=============================>                     ]  568.3MB/969.2MB
# Push output: Pushing [=============================>                     ]  573.9MB/969.2MB
# Push output: Pushing [=============================>                     ]  578.3MB/969.2MB
# Push output: Pushing [=============================>                     ]  581.1MB/969.2MB
# Push output: Pushing [==============================>                    ]  584.4MB/969.2MB
# Push output: Pushing [==============================>                    ]  586.7MB/969.2MB
# Push output: Pushing [==============================>                    ]  588.9MB/969.2MB
# Push output: Pushing [==============================>                    ]  592.2MB/969.2MB
# Push output: Pushing [==============================>                    ]  594.5MB/969.2MB
# Push output: Pushing [==============================>                    ]  596.1MB/969.2MB
# Push output: Pushing [==============================>                    ]  597.8MB/969.2MB
# Push output: Pushing [==============================>                    ]    600MB/969.2MB
# Push output: Pushing [===============================>                   ]  606.2MB/969.2MB
# Push output: Pushing [===============================>                   ]    614MB/969.2MB
# Push output: Pushing [================================>                  ]  623.4MB/969.2MB
# Push output: Pushing [================================>                  ]  630.7MB/969.2MB
# Push output: Pushing [================================>                  ]  637.9MB/969.2MB
# Push output: Pushing [=================================>                 ]  645.2MB/969.2MB
# Push output: Pushing [=================================>                 ]  649.5MB/969.2MB
# Push output: Pushing [=================================>                 ]  651.7MB/969.2MB
# Push output: Pushing [=================================>                 ]  654.4MB/969.2MB
# Push output: Pushing [=================================>                 ]  657.1MB/969.2MB
# Push output: Pushing [==================================>                ]  659.8MB/969.2MB
# Push output: Pushing [==================================>                ]    663MB/969.2MB
# Push output: Pushing [==================================>                ]  665.6MB/969.2MB
# Push output: Pushing [==================================>                ]  670.5MB/969.2MB
# Push output: Pushing [==================================>                ]  673.2MB/969.2MB
# Push output: Pushing [==================================>                ]  675.8MB/969.2MB
# Push output: Pushing [===================================>               ]    679MB/969.2MB
# Push output: Pushing [===================================>               ]  681.7MB/969.2MB
# Push output: Pushing [===================================>               ]  683.9MB/969.2MB
# Push output: Pushing [===================================>               ]  686.6MB/969.2MB
# Push output: Pushing [===================================>               ]  688.7MB/969.2MB
# Push output: Pushing [===================================>               ]  691.4MB/969.2MB
# Push output: Pushing [===================================>               ]  693.7MB/969.2MB
# Push output: Pushing [===================================>               ]  696.4MB/969.2MB
# Push output: Pushing [====================================>              ]  699.2MB/969.2MB
# Push output: Pushing [====================================>              ]  701.5MB/969.2MB
# Push output: Pushing [====================================>              ]  703.7MB/969.2MB
# Push output: Pushing [====================================>              ]  705.9MB/969.2MB
# Push output: Pushing [====================================>              ]  709.8MB/969.2MB
# Push output: Pushing [====================================>              ]  712.6MB/969.2MB
# Push output: Pushing [====================================>              ]  715.4MB/969.2MB
# Push output: Pushing [=====================================>             ]  718.2MB/969.2MB
# Push output: Pushing [=====================================>             ]    721MB/969.2MB
# Push output: Pushing [=====================================>             ]  723.7MB/969.2MB
# Push output: Pushing [=====================================>             ]  726.5MB/969.2MB
# Push output: Pushing [=====================================>             ]  728.8MB/969.2MB
# Push output: Pushing [=====================================>             ]  731.5MB/969.2MB
# Push output: Pushing [=====================================>             ]  734.3MB/969.2MB
# Push output: Pushing [======================================>            ]  737.1MB/969.2MB
# Push output: Pushing [======================================>            ]    741MB/969.2MB
# Push output: Pushing [======================================>            ]  744.4MB/969.2MB
# Push output: Pushing [======================================>            ]  746.6MB/969.2MB
# Push output: Pushing [======================================>            ]  748.8MB/969.2MB
# Push output: Pushing [======================================>            ]  751.6MB/969.2MB
# Push output: Pushing [======================================>            ]  754.9MB/969.2MB
# Push output: Pushing [=======================================>           ]  757.7MB/969.2MB
# Push output: Pushing [=======================================>           ]  760.5MB/969.2MB
# Push output: Pushing [=======================================>           ]  762.7MB/969.2MB
# Push output: Pushing [=======================================>           ]    765MB/969.2MB
# Push output: Pushing [=======================================>           ]  767.2MB/969.2MB
# Push output: Pushing [=======================================>           ]  768.9MB/969.2MB
# Push output: Pushing [=======================================>           ]  771.1MB/969.2MB
# Push output: Pushing [=======================================>           ]  773.3MB/969.2MB
# Push output: Pushing [========================================>          ]  775.5MB/969.2MB
# Push output: Pushing [========================================>          ]  777.8MB/969.2MB
# Push output: Pushing [========================================>          ]    780MB/969.2MB
# Push output: Pushing [========================================>          ]  782.2MB/969.2MB
# Push output: Pushing [========================================>          ]  784.5MB/969.2MB
# Push output: Pushing [========================================>          ]  786.7MB/969.2MB
# Push output: Pushing [========================================>          ]  788.9MB/969.2MB
# Push output: Pushing [========================================>          ]  791.1MB/969.2MB
# Push output: Pushing [========================================>          ]  792.8MB/969.2MB
# Push output: Pushing [=========================================>         ]    795MB/969.2MB
# Push output: Pushing [=========================================>         ]  797.3MB/969.2MB
# Push output: Pushing [=========================================>         ]  799.5MB/969.2MB
# Push output: Pushing [=========================================>         ]  801.7MB/969.2MB
# Push output: Pushing [=========================================>         ]    804MB/969.2MB
# Push output: Pushing [=========================================>         ]  806.2MB/969.2MB
# Push output: Pushing [=========================================>         ]  808.4MB/969.2MB
# Push output: Pushing [=========================================>         ]  810.6MB/969.2MB
# Push output: Pushing [=========================================>         ]  812.9MB/969.2MB
# Push output: Pushing [==========================================>        ]  815.1MB/969.2MB
# Push output: Pushing [==========================================>        ]  817.3MB/969.2MB
# Push output: Pushing [==========================================>        ]  819.6MB/969.2MB
# Push output: Pushing [==========================================>        ]  821.8MB/969.2MB
# Push output: Pushing [==========================================>        ]    824MB/969.2MB
# Push output: Pushing [==========================================>        ]  826.2MB/969.2MB
# Push output: Pushing [==========================================>        ]  828.5MB/969.2MB
# Push output: Pushing [==========================================>        ]  830.7MB/969.2MB
# Push output: Pushing [==========================================>        ]  832.9MB/969.2MB
# Push output: Pushing [===========================================>       ]  835.2MB/969.2MB
# Push output: Pushing [===========================================>       ]  837.9MB/969.2MB
# Push output: Pushing [===========================================>       ]  840.1MB/969.2MB
# Push output: Pushing [===========================================>       ]  842.3MB/969.2MB
# Push output: Pushing [===========================================>       ]  845.1MB/969.2MB
# Push output: Pushing [===========================================>       ]  847.9MB/969.2MB
# Push output: Pushing [===========================================>       ]  850.7MB/969.2MB
# Push output: Pushing [============================================>      ]  853.5MB/969.2MB
# Push output: Pushing [============================================>      ]  856.8MB/969.2MB
# Push output: Pushing [============================================>      ]  860.1MB/969.2MB
# Push output: Pushing [============================================>      ]  862.9MB/969.2MB
# Push output: Pushing [============================================>      ]  865.7MB/969.2MB
# Push output: Pushing [============================================>      ]  868.5MB/969.2MB
# Push output: Pushing [============================================>      ]  871.3MB/969.2MB
# Push output: Pushing [=============================================>     ]  874.1MB/969.2MB
# Push output: Pushing [=============================================>     ]  876.3MB/969.2MB
# Push output: Pushing [=============================================>     ]  879.1MB/969.2MB
# Push output: Pushing [=============================================>     ]  881.9MB/969.2MB
# Push output: Pushing [=============================================>     ]  884.6MB/969.2MB
# Push output: Pushing [=============================================>     ]  888.5MB/969.2MB
# Push output: Pushing [==============================================>    ]  891.9MB/969.2MB
# Push output: Pushing [==============================================>    ]  894.1MB/969.2MB
# Push output: Pushing [==============================================>    ]  896.3MB/969.2MB
# Push output: Pushing [==============================================>    ]  899.1MB/969.2MB
# Push output: Pushing [==============================================>    ]  902.5MB/969.2MB
# Push output: Pushing [==============================================>    ]  905.8MB/969.2MB
# Push output: Pushing [==============================================>    ]    908MB/969.2MB
# Push output: Pushing [==============================================>    ]  910.3MB/969.2MB
# Push output: Pushing [===============================================>   ]  911.9MB/969.2MB
# Push output: Pushing [===============================================>   ]  914.2MB/969.2MB
# Push output: Pushing [===============================================>   ]  916.4MB/969.2MB
# Push output: Pushing [===============================================>   ]  918.6MB/969.2MB
# Push output: Pushing [===============================================>   ]  921.4MB/969.2MB
# Push output: Pushing [===============================================>   ]    922MB/969.2MB
# Push output: Pushing [===============================================>   ]  923.1MB/969.2MB
# Push output: Pushing [===============================================>   ]  924.2MB/969.2MB
# Push output: Pushing [===============================================>   ]  925.9MB/969.2MB
# Push output: Pushing [===============================================>   ]    927MB/969.2MB
# Push output: Pushing [===============================================>   ]  928.1MB/969.2MB
# Push output: Pushing [===============================================>   ]  929.2MB/969.2MB
# Push output: Pushing [===============================================>   ]  930.3MB/969.2MB
# Push output: Pushing [================================================>  ]    932MB/969.2MB
# Push output: Pushing [================================================>  ]  933.1MB/969.2MB
# Push output: Pushing [================================================>  ]  935.3MB/969.2MB
# Push output: Pushing [================================================>  ]  936.5MB/969.2MB
# Push output: Pushing [================================================>  ]  938.7MB/969.2MB
# Push output: Pushing [================================================>  ]  940.4MB/969.2MB
# Push output: Pushing [================================================>  ]  942.6MB/969.2MB
# Push output: Pushing [================================================>  ]  944.8MB/969.2MB
# Push output: Pushing [================================================>  ]  945.4MB/969.2MB
# Push output: Pushing [================================================>  ]  948.2MB/969.2MB
# Push output: Pushing [=================================================> ]  950.9MB/969.2MB
# Push output: Pushing [=================================================> ]  953.2MB/969.2MB
# Push output: Pushing [=================================================> ]  954.3MB/969.2MB
# Push output: Pushing [=================================================> ]  956.5MB/969.2MB
# Push output: Pushing [=================================================> ]  959.3MB/969.2MB
# Push output: Pushing [=================================================> ]  962.1MB/969.2MB
# Push output: Pushing [=================================================> ]  964.3MB/969.2MB
# Push output: Pushing [=================================================> ]    966MB/969.2MB
# Push output: Pushing [=================================================> ]  968.2MB/969.2MB
# Push output: Pushing [==================================================>]  970.4MB
# Push output: Pushing [==================================================>]  972.7MB
# Push output: Pushing [==================================================>]  974.9MB
# Push output: Pushing [==================================================>]  977.1MB
# Push output: Pushing [==================================================>]  979.3MB
# Push output: Pushing [==================================================>]  981.6MB
# Push output: Pushing [==================================================>]  983.8MB
# Push output: Pushed None
# Push output: 26A3FC51: digest: sha256:0707e4936f021f6eb2e9f6f65d6beff2edfb46d7a1293a8924a24b844924b63a size: 3054 None
# Push finished: {'Tag': '26A3FC51', 'Digest': 'sha256:0707e4936f021f6eb2e9f6f65d6beff2edfb46d7a1293a8924a24b844924b63a', 'Size': 3054}
# Training job fairing-job-x82rk launched.
# Waiting for fairing-job-x82rk-8fs2c to start...
# Pod started running True
# [01:59:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:177514
# Will train until validation_0-rmse hasn't improved in 40 rounds.
# [1]	validation_0-rmse:161858
# [2]	validation_0-rmse:147237
# [3]	validation_0-rmse:134132
# [4]	validation_0-rmse:122224
# [5]	validation_0-rmse:111538
# [6]	validation_0-rmse:102142
# [7]	validation_0-rmse:93392.3
# [8]	validation_0-rmse:85824.6
# [9]	validation_0-rmse:79667.6
# [10]	validation_0-rmse:73463.4
# [11]	validation_0-rmse:68059.4
# [12]	validation_0-rmse:63350.5
# [13]	validation_0-rmse:59732.1
# [14]	validation_0-rmse:56260.7
# [15]	validation_0-rmse:53392.6
# [16]	validation_0-rmse:50770.8
# [17]	validation_0-rmse:48107.8
# [18]	validation_0-rmse:45923.9
# [19]	validation_0-rmse:44154.2
# [20]	validation_0-rmse:42488.1
# [21]	validation_0-rmse:41263.3
# [22]	validation_0-rmse:40212.8
# [23]	validation_0-rmse:39089.1
# [24]	validation_0-rmse:37691.1
# [25]	validation_0-rmse:36875.2
# [26]	validation_0-rmse:36276.2
# [27]	validation_0-rmse:35444.1
# [28]	validation_0-rmse:34831.5
# [29]	validation_0-rmse:34205.4
# [30]	validation_0-rmse:33831.9
# [31]	validation_0-rmse:33183.6
# [32]	validation_0-rmse:33019.4
# [33]	validation_0-rmse:32680
# [34]	validation_0-rmse:32438.5
# [35]	validation_0-rmse:32130.4
# [36]	validation_0-rmse:31644.2
# [37]	validation_0-rmse:31248.9
# [38]	validation_0-rmse:31059.8
# [39]	validation_0-rmse:30862.4
# [40]	validation_0-rmse:30754
# [41]	validation_0-rmse:30561.6
# [42]	validation_0-rmse:30416.9
# [43]	validation_0-rmse:30156.4
# [44]	validation_0-rmse:29852.9
# [45]	validation_0-rmse:29486.6
# [46]	validation_0-rmse:29158.8
# [47]	validation_0-rmse:29017
# [48]	validation_0-rmse:28973.9
# [49]	validation_0-rmse:28787.7
# mean_absolute_error=18173.15
# Model export success: trained_ames_model.dat
# Best RMSE on eval: %.2f with %d rounds 28787.720703 50
# Cleaning up job fairing-job-x82rk...
# 'fairing-job-x82rk'

# %% [markdown]
# ## Train an XGBoost model remotely on Cloud ML Engine
#
# Import the `TrainJob` and `GCPManagedBackend` classes. Kubeflow Fairing packages the `HousingServe` class, the training data, and the training job's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the training job on Cloud ML Engine.

# %%
from fairing import TrainJob
from fairing.backends import GCPManagedBackend
train_job = TrainJob(HousingServe, BASE_IMAGE, input_files=['ames_dataset/train.csv', "requirements.txt"],
                     docker_registry=DOCKER_REGISTRY, backend=GCPManagedBackend())
train_job.submit()

# %% [markdown]
# ## Deploy the trained model to Kubeflow for predictions
#
# Import the `PredictionEndpoint` and `KubeflowGKEBackend` classes. Kubeflow Fairing packages the `HousingServe` class, the trained model, and the prediction endpoint's software prerequisites as a Docker image. Then Kubeflow Fairing deploys and runs the prediction endpoint on Kubeflow.

# %%
from fairing import PredictionEndpoint
from fairing.backends import KubeflowGKEBackend
endpoint = PredictionEndpoint(HousingServe, BASE_IMAGE, input_files=['trained_ames_model.dat', "requirements.txt"],
                              docker_registry=DOCKER_REGISTRY, backend=KubeflowGKEBackend())
endpoint.create()
# Out:
# Using builder: <class 'fairing.builders.docker.docker.DockerBuilder'>
# Building the docker image.
# Building image using docker
# Docker command: ['python', '/app/function_shim.py', '--serialized_fn_file', '/app/pickled_fn.p']
# /Users/cartick/Documents/workspace/fairing/venv/lib/python3.7/site-packages/fairing/__init__.py already exists in Fairing context, skipping...
# Creating docker context: /tmp/fairing_context_n0my892f
# /Users/cartick/Documents/workspace/fairing/venv/lib/python3.7/site-packages/fairing/__init__.py already exists in Fairing context, skipping...
# Building docker image gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:FBDDFE2A...
# Build output: Step 1/7 : FROM python:3.7.2
# Build output:
# Build output: ---> 2053ca75899e
# Build output: Step 2/7 : WORKDIR /app/
# Build output:
# Build output: ---> Using cache
# Build output: ---> 2c7f8a216fa8
# Build output: Step 3/7 : ENV FAIRING_RUNTIME 1
# Build output:
# Build output: ---> Using cache
# Build output: ---> 13640ae5453f
# Build output: Step 4/7 : COPY /app//requirements.txt /app/
# Build output:
# Build output: ---> Using cache
# Build output: ---> 65b03bec95c5
# Build output: Step 5/7 : RUN if [ -e requirements.txt ];then pip install --no-cache -r requirements.txt; fi
# Build output:
# Build output: ---> Using cache
# Build output: ---> cf9bd5ec2ec1
# Build output: Step 6/7 : COPY /app/ /app/
# Build output:
# Build output: ---> 66ac0a25e616
# Build output: Step 7/7 : CMD python /app/function_shim.py --serialized_fn_file /app/pickled_fn.p
# Build output:
# Build output: ---> Running in 16fd4e6bfe6e
# Build output: ---> 70234800c14a
# Push finished: {'ID': 'sha256:70234800c14ac74dd6ca7db25fb808ebbd90f1bbe662ce9bf9b1a27b80374df4'}
# Build output: Successfully built 70234800c14a
# Build output: Successfully tagged gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:FBDDFE2A
# Publishing image gcr.io/caip-dexter-bugbash/fairing-job/fairing-job:FBDDFE2A...
# Push output: The push refers to repository [gcr.io/caip-dexter-bugbash/fairing-job/fairing-job] None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Preparing None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Waiting None
# Push output: Pushing [>                                                  ]  1.024kB/89.25kB
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Pushing [==================================================>]  98.82kB
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Layer already exists None
# Push output: Pushed None
# Push output: FBDDFE2A: digest: sha256:719afe13af03e6ccad0294a3e64a59e6c57229c758b9f4fb1fd8333820682102 size: 3053 None
# Push finished: {'Tag': 'FBDDFE2A', 'Digest': 'sha256:719afe13af03e6ccad0294a3e64a59e6c57229c758b9f4fb1fd8333820682102', 'Size': 3053}
# Deploying the endpoint.
# Waiting for prediction endpoint to come up...
# Cluster endpoint: http://35.226.32.152:5000/predict
# Prediction endpoint: http://35.226.32.152:5000/predict

# %% [markdown]
# ## Call the prediction endpoint
#
# Create a test dataset, then call the endpoint on Kubeflow for predictions.

# %%
(train_X, train_y), (test_X, test_y) = read_input("ames_dataset/train.csv")
endpoint.predict_nparray(test_X)
# Out:
# {"data":{"names":["t:0","t:1"],"tensor":{"shape":[1,2],"values":[165164.875,165164.875]}},"meta":{}}

# %% [markdown]
# ## Clean up the prediction endpoint
#
# Delete the prediction endpoint created by this notebook.

# %%
endpoint.delete()
# Out:
# Deleted service: kubeflow/fairing-service-r5hgd
# Deleted deployment: kubeflow/fairing-deployer-2dstt
